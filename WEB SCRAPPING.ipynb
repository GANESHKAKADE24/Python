# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers= {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=2',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
li=[]
for i in range(30):
    li.append(soup.find_all('h2')[i].text.strip())
    
print(li)
# Out:
# ['IndusInd Bank', 'Ernst & Young', 'DXC Technology', 'Hinduja Global S...', 'Infosys BPM', 'Maruti Suzuki', 'IDFC FIRST Bank', 'HSBC', 'Bajaj Finserv', 'Ericsson', 'Conneqt Business...', 'Mphasis', 'Startek', "Dr. Reddy's", 'Sutherland Globa...', 'Cipla Pharmaceut...', 'Yes Bank', 'Udaan', 'Jana Small Finan...', 'Asian Paints', 'NTT DATA', 'ICICI Prudential...', 'HDFC Life', 'Lupin', 'HCL Group', 'PwC', 'EXL Service', 'iEnergizer', 'L&T Infotech', 'Indian Army']

# %%
company=soup.find_all('div',class_=('company-content'))

# %%
len(company)
# Out:
# 30

# %%
import numpy as np

# %%
name=[]
rating=[]
reviews=[]
typen=[]
loc=[]

empl=[]
for i in comapny:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p').text.strip())
    reviews.append(i.find('a',class_=('review-count')).text.strip())
    typen.append(i.find_all('p',class_=('infoEntity'))[0].text.strip())
    
    try:
        loc.append(i.find_all('p',class_=('infoEntity'))[1].text.strip())
        empl.append(i.find_all('p',class_=('infoEntity'))[3].text.strip())
    except:
        
        loc.append(np.nan)
        empl.append(np.nan)
        
d= {'name':name,'rating':rating,'reviews':reviews,'typen':typen,'empl':empl}
   
final=pd.DataFrame(d)

 
final
# Out:
#                    name rating          reviews  \
# 0         IndusInd Bank    3.8   (6.6k Reviews)
# 1         Ernst & Young    3.8   (6.3k Reviews)
# 2        DXC Technology    3.9     (7k Reviews)
# 3   Hinduja Global S...    4.0     (6k Reviews)
# 4           Infosys BPM    4.0   (5.8k Reviews)
# 5         Maruti Suzuki    4.2   (5.8k Reviews)
# 6       IDFC FIRST Bank    4.0   (5.3k Reviews)
# 7                  HSBC    4.1   (5.7k Reviews)
# 8         Bajaj Finserv    4.0   (5.2k Reviews)
# 9              Ericsson    4.3   (5.3k Reviews)
# 10  Conneqt Business...    3.7   (5.1k Reviews)
# 11              Mphasis    3.7   (4.8k Reviews)
# 12              Startek    3.4   (4.8k Reviews)
# 13          Dr. Reddy's    4.2   (4.8k Reviews)
# 14  Sutherland Globa...    3.8     (5k Reviews)
# 15  Cipla Pharmaceut...    4.1   (4.7k Reviews)
# 16             Yes Bank    4.0   (4.5k Reviews)
# 17                Udaan    4.1   (4.5k Reviews)
# ...
